# %% [markdown]
# # Exercício

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=c=e=[i for i in range(1,13)]
b=[15,4,4,6,8,10,10,12,14,12,10,10]
d=[12,7,7,9,11,13,8,15,17,15,13,17]
f=[5,10,5,4,23,1,9,4,12,19,23,2]
plt.plot(a,b)
plt.plot(c,d)
plt.plot(e,f)

# %%
#figure altera o tamanho do gráfico
#Para o eixoY quando der errado com a divisão perfeita, basta dividir o ponto mais alto por 2 e depois dividir as metades
#pelas respectivas quantidades
plt.figure(figsize=(8,5))
eixoY=['Péssimo','Fraco','Regular','Neutro','Bom','Ótimo','Excelente']
eixoX=['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']
plt.xticks([i for i in range(1,13)],eixoX,rotation=30)
plt.yticks([0,3.83,7.66,11.5,15.33,19.16,23],eixoY)
plt.title('Produção-2018')
plt.ylabel('Classificação')
plt.plot(a,b,c='blue',ls='--',lw=1,marker='^',label='Funcionário A')
plt.plot(c,d,c='red',ls='--',lw=1,marker='o',label='Funcionário B')
plt.plot(e,f,c='purple',ls='--',lw=1,marker='x',label='Funcionário C')
plt.legend(loc='upper left')
