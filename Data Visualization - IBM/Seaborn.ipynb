# %% [markdown]
# # Regression Plots

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_can=pd.read_excel('Canada.xlsx',sheet_name='Canada by Citizenship',skiprows=20,skipfooter=2)
df_can.columns.astype(str,copy=False)
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...   2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...   2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...   1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...   3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...      0     0     1
# 4  Southern Europe  901   Developed regions     0  ...      0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_regre=df_can.copy()
df_regre.drop(['Type','Coverage','OdName','AREA','AreaName','REG','RegName','DEV','DevName'],axis=1,inplace=True)
df_regre=pd.DataFrame(df_regre.sum())
df_regre.reset_index(inplace=True)
df_regre.rename(columns={'index':'year',0:'total'},inplace=True)
df_regre.astype(int,copy=False)
df_regre.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
ax=sns.regplot(x='year',y='total',data=df_regre)

# %%
sns.get_dataset_names()
# Out:
# C:\Users\Arthur\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\Arthur\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Pivotamento
fly=sns.load_dataset('flights')
fly=fly.pivot_table(values='passengers',index='month',columns='year')
fly.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %% [markdown]
# ## Histogram

# %%
sns.distplot(tips['tip'],bins=20)

# %% [markdown]
# ## Linear Graphs

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
titanic=sns.load_dataset('titanic')
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.jointplot(x='size',y='tip',data=tips)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='Spectral')

# %%
sns.pairplot(tips,hue='smoker',palette='YlGnBu')

# %% [markdown]
# ## Categorical

# %%
sns.countplot(x='sex',data=titanic)

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x='day',y='tip',data=tips)

# %%
sns.boxplot(x='day',y='tip',data=tips,hue='sex')

# %% [markdown]
# ## Strip plot

# %%
sns.stripplot(x='day',y='tip',data=tips)

# %%
sns.swarmplot(x='day',y='tip',data=tips)

# %% [markdown]
# ## Correlation

# %%
correla=tips.corr()
sns.heatmap(correla,annot=True)

# %%
sns.heatmap(fly)

# %%
sns.clustermap(fly)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='time',col='time')
