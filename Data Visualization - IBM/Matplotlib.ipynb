# %% [markdown]
# ## Creating a histogram of some data

# %%
#Artist Layer
#AGG anti grain geometry
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
# %matplotlib inline
fig=Figure()
canvas=FigureCanvas(fig)
#Create 10000 random numbers using numpy
import numpy as np
x=np.random.randn(10000)
ax=fig.add_subplot(111) #Create an axes artist    | 1 row | 1 column | 1 cell
ax.hist(x,100)#Create a histogram with 1000
ax.set_title('Normal distribution with $\mu=0, \sigma=1$')
fig.savefig('matplotlib_histogram.png')

# %%
#Scripting Layer
#Will create a histogram with all data and separate them in 100 bars
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.random.randn(10000)
plt.hist(x,100)
plt.title('Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib_histogram.png')
plt.show()

# %% [markdown]
# # Basic Visualization Tools

# %% [markdown]
# ## Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
'''
#Reading a file from html website
#In this case its impossible because the current link now have to login and its no more public
df_canada=pd.read_excel('https://ibm.box.com/shared/static/lw190pt9zpy5bd1ptyg2aw15awomz9pu.xlsx',
                        sheetname='Canada by Citizenship',
                       skiprows=range(20)
                       skipfooter=2)
'''
df_can=pd.read_excel('Canada.xlsx',sheet_name='Canada by Citizenship',skiprows=range(20),skipfooter=2)
df_can.columns=df_can.columns.astype(str)
years=[str(i) for i in range(1980,2014)]
df_can['Total']=df_can[years].sum(axis=1)
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...    2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...    3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...    1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...    3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...       0     1     0
# 4  Southern Europe  901   Developed regions     0  ...       0     1     1
#
#    2008  2009  2010  2011  2012  2013  Total
# 0  2111  1746  1758  2203  2635  2004  58639
# ...

# %%
df_canada=df_can.copy().set_index(df_can.OdName)
df_canada.loc['Haiti',years].plot(kind='line')
plt.title('Immigration from Haiti')
plt.xlabel('Year')
plt.ylabel('Number of immigrants')
plt.show()

# %% [markdown]
# ## Area Plot

# %%
df_canada.sort_values(['Total'],ascending=False,axis=0)
# Out:
#                                                           Type    Coverage  \
# OdName
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# United States of America                            Immigrants  Foreigners
# Iran (Islamic Republic of)                          Immigrants  Foreigners
# Sri Lanka                                           Immigrants  Foreigners
# Republic of Korea                                   Immigrants  Foreigners
# Poland                                              Immigrants  Foreigners
# Lebanon                                             Immigrants  Foreigners
# ...

# %%
df_top5=df_canada.sort_values(['Total'],ascending=False,axis=0).head()
df_top5=df_top5[years].transpose()
df_top5.rename(columns={'United Kingdom of Great Britain and Northern Ireland':'United Kingdom'},inplace=True)
df_top5.columns.name=''
df_top5.head()
# Out:
#       India  China  United Kingdom  Philippines  Pakistan
# 1980   8880   5123           22045         6051       978
# 1981   8670   6682           24796         5921       972
# 1982   8147   3308           20620         5249      1201
# 1983   7338   1863           10015         4562       900
# 1984   5704   1527           10170         3801       668

# %%
df_top5.plot(kind='area')
plt.title('Immigration trend of top 5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ## Histogram

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...    2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...    3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...    1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...    3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...       0     1     0
# 4  Southern Europe  901   Developed regions     0  ...       0     1     1
#
#    2008  2009  2010  2011  2012  2013  Total
# 0  2111  1746  1758  2203  2635  2004  58639
# ...

# %%
df_canada=df_can.copy()
count,bin_edges=np.histogram(df_canada['2013'])
df_canada['2013'].plot(kind='hist',xticks=bin_edges,rot=30)
plt.xlabel('Number of immigrants')
plt.ylabel('Number of Countries')
plt.title('Histogram of Immigrantion from 195 countries in 2013')
# Out:
# Text(0.5, 1.0, 'Histogram of Immigrantion from 195 countries in 2013')

# %% [markdown]
# ## Bar Charts

# %%
df_canada=df_can.copy()
df_canada.drop(['Type','Coverage','AREA','REG','DEV'],axis=1,inplace=True)
df_canada.rename(columns={'RegName':'Region','AreaName':'Continent'})
df_canada.set_index(df_canada.OdName,inplace=True)
df_canada.drop(['OdName'],axis=1,inplace=True)
df_canada.index.name='Country'
df_canada.head()
# Out:
#                AreaName          RegName             DevName  1980  1981  \
# Country
# Afghanistan        Asia    Southern Asia  Developing regions    16    39
# Albania          Europe  Southern Europe   Developed regions     1     0
# Algeria          Africa  Northern Africa  Developing regions    80    67
# American Samoa  Oceania        Polynesia  Developing regions     0     1
# Andorra          Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...    2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...    3436  3009  2652  2111
# Albania            0     0     0     0     1  ...    1223   856   702   560
# Algeria           71    69    63    44    69  ...    3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...       0     1     0     0
# Andorra            0     0     0     0     2  ...       0     1     1     0
#
# ...

# %%
years=[str(i) for i in range(1980,2014)]
df_iceland=df_canada.loc['Iceland',years]
df_iceland.plot(kind='barh',figsize=(7,8))
plt.xlabel('Number of immigrants')
plt.ylabel('Year')
plt.title('Icelandic immigrants to Canada from 1980 to 2013')
# Out:
# Text(0.5, 1.0, 'Icelandic immigrants to Canada from 1980 to 2013')

# %% [markdown]
# # Specialized Visualization Tools

# %% [markdown]
# ## Pie Charts

# %%
df_canada.head()
# Out:
#                AreaName          RegName             DevName  1980  1981  \
# Country
# Afghanistan        Asia    Southern Asia  Developing regions    16    39
# Albania          Europe  Southern Europe   Developed regions     1     0
# Algeria          Africa  Northern Africa  Developing regions    80    67
# American Samoa  Oceania        Polynesia  Developing regions     0     1
# Andorra          Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...    2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...    3436  3009  2652  2111
# Albania            0     0     0     0     1  ...    1223   856   702   560
# Algeria           71    69    63    44    69  ...    3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...       0     1     0     0
# Andorra            0     0     0     0     2  ...       0     1     1     0
#
# ...

# %%
df_continents=df_canada.groupby(['AreaName'],axis=0).sum()
df_continents.head()
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# AreaName
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989   ...       2005  \
# AreaName                                                      ...
# Africa                            3782   7494   7552   9894   ...      27523
# Asia                             28739  43203  47454  60256   ...     159253
# Europe                           24370  46698  54726  60893   ...      35955
# Latin America and the Caribbean  21179  28471  21924  25060   ...      24747
# ...

# %%
df_continents.Total.plot(kind='pie')
plt.title('Immigration to Canada by Continent (1980-2013)')
# Out:
# Text(0.5, 1.0, 'Immigration to Canada by Continent (1980-2013)')

# %% [markdown]
# ## Box Plots

# %%
df_canada.head()
# Out:
#                AreaName          RegName             DevName  1980  1981  \
# Country
# Afghanistan        Asia    Southern Asia  Developing regions    16    39
# Albania          Europe  Southern Europe   Developed regions     1     0
# Algeria          Africa  Northern Africa  Developing regions    80    67
# American Samoa  Oceania        Polynesia  Developing regions     0     1
# Andorra          Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...    2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...    3436  3009  2652  2111
# Albania            0     0     0     0     1  ...    1223   856   702   560
# Algeria           71    69    63    44    69  ...    3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...       0     1     0     0
# Andorra            0     0     0     0     2  ...       0     1     1     0
#
# ...

# %%
df_brazil=df_canada.copy().loc['Brazil',years].transpose()
df_brazil.plot(kind='box')
plt.title('Box plot of Brazillian Immigrants from (1980-2013)')
plt.ylabel('Number of Immigrants')
# Out:
# Text(0, 0.5, 'Number of Immigrants')

# %% [markdown]
# ## Scatter Plot

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...    2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...    3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...    1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...    3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...       0     1     0
# 4  Southern Europe  901   Developed regions     0  ...       0     1     1
#
#    2008  2009  2010  2011  2012  2013  Total
# 0  2111  1746  1758  2203  2635  2004  58639
# ...

# %%
df_total=df_can.copy()
df_total.drop(['Type','Coverage','OdName','AREA','AreaName','REG','RegName','DEV','DevName','Total'],axis=1,
             inplace=True)
df_total=pd.DataFrame(df_total.sum())
df_total.reset_index(inplace=True)
df_total.rename(columns={'index':'year',0:'total'},inplace=True)
df_total['year']=df_total['year'].astype(int)
df_total.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_total.plot(kind='scatter',x='year',y='total')
plt.title('Total Immigrant population to Canada from (1980-2013)')
plt.xlabel('Year')
plt.ylabel('Number of immigrants')
# Out:
# Text(0, 0.5, 'Number of immigrants')

# %% [markdown]
# # Advanced Visualization Tools

# %% [markdown]
# ## Waffle Charts

# %%
from pywaffle import Waffle
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...    2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...    3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...    1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...    3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...       0     1     0
# 4  Southern Europe  901   Developed regions     0  ...       0     1     1
#
#    2008  2009  2010  2011  2012  2013  Total
# 0  2111  1746  1758  2203  2635  2004  58639
# ...

# %%
'''
We can do that way, which is a pretty hard way or we can use the created function bellow the waffle chart
'''
df_imigration=df_can.copy()
to_drop=['Type','Coverage','AREA','AreaName','REG','RegName','DEV','DevName']
to_drop+=years
df_imigration=df_imigration.drop(to_drop,axis=1)
df_imigration.columns=df_imigration.columns.str.replace('OdName','Country').str.replace('Total','Total Immigrants')
df_imigration=df_imigration[(df_imigration.Country=='Denmark')|(df_imigration.Country=='Sweden')|
                            (df_imigration.Country=='Norway')]
df_imigration.index=range(3)
plt.figure(figsize=(9,4),FigureClass=Waffle,rows=10,columns=50,values=df_imigration['Total Immigrants'],
           labels=list(df_imigration.Country))
plt.savefig('waffle_charts.png')
# Out:
# C:\Users\Arthur\AppData\Roaming\Python\Python37\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# <Waffle size 648x288 with 1 Axes>

# %%
df_dsn=df_canada.copy().loc[['Denmark','Norway','Sweden'],:]
df_dsn
# Out:
#         AreaName          RegName            DevName  1980  1981  1982  1983  \
# Country
# Denmark   Europe  Northern Europe  Developed regions   272   293   299   106
# Norway    Europe  Northern Europe  Developed regions   116    77   106    51
# Sweden    Europe  Northern Europe  Developed regions   281   308   222   176
#
#          1984  1985  1986  ...    2005  2006  2007  2008  2009  2010  2011  \
# Country                    ...
# Denmark    93    73    93  ...      62   101    97   108    81    92    93
# Norway     31    54    56  ...      57    53    73    66    75    46    49
# Sweden    128   158   187  ...     205   139   193   165   167   159   134
#
#          2012  2013  Total
# Country
# Denmark    94    81   3901
# Norway     53    59   2327
# Sweden    140   140   5866
#
# [3 rows x 38 columns]

# %%
def create_waffle_chart(categories, values, height, width, colormap, value_sign=''):
    import matplotlib.patches as mpatches

    # compute the proportion of each category with respect to the total
    total_values = sum(values)
    category_proportions = [(float(value) / total_values) for value in values]

    # compute the total number of tiles
    total_num_tiles = width * height # total number of tiles
    print ('Total number of tiles is', total_num_tiles)
    
    # compute the number of tiles for each catagory
    tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

    # print out number of tiles per category
    for i, tiles in enumerate(tiles_per_category):
        print (df_dsn.index.values[i] + ': ' + str(tiles))
    
    # initialize the waffle chart as an empty matrix
    waffle_chart = np.zeros((height, width))

    # define indices to loop through waffle chart
    category_index = 0
    tile_index = 0

    # populate the waffle chart
    for col in range(width):
        for row in range(height):
            tile_index += 1

            # if the number of tiles populated for the current category 
            # is equal to its corresponding allocated tiles...
            if tile_index > sum(tiles_per_category[0:category_index]):
                # ...proceed to the next category
                category_index += 1       
            
            # set the class value to an integer, which increases with class
            waffle_chart[row, col] = category_index
    
    # instantiate a new figure object
    fig = plt.figure()

    # use matshow to display the waffle chart
    colormap = plt.cm.coolwarm
    plt.matshow(waffle_chart, cmap=colormap)
    plt.colorbar()

    # get the axis
    ax = plt.gca()

    # set minor ticks
    ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
    ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
    # add dridlines based on minor ticks
    ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

    plt.xticks([])
    plt.yticks([])

    # compute cumulative sum of individual categories to match color schemes between chart and legend
    values_cumsum = np.cumsum(values)
    total_values = values_cumsum[len(values_cumsum) - 1]

    # create legend
    legend_handles = []
    for i, category in enumerate(categories):
        if value_sign == '%':
            label_str = category + ' (' + str(values[i]) + value_sign + ')'
        else:
            label_str = category + ' (' + value_sign + str(values[i]) + ')'
            
        color_val = colormap(float(values_cumsum[i])/total_values)
        legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

    # add legend to chart
    plt.legend(
        handles=legend_handles,
        loc='lower center', 
        ncol=len(categories),
        bbox_to_anchor=(0., -0.2, 0.95, .1)

    )

# %%
width = 40 # width of chart
height = 10 # height of chart

categories = df_dsn.index.values # categories
values = df_dsn['Total'] # correponding values of categories

colormap = plt.cm.coolwarm # color map class

# %%
create_waffle_chart(categories,values,height,width,colormap)
# Out:
# Total number of tiles is 400
# Denmark: 129
# Norway: 77
# Sweden: 194

# %% [markdown]
# ## Word Clouds

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# open the file and read it into a variable alice_novel
alice_novel = open('alice_novel.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)
# generate the word cloud
alice_wc.generate(alice_novel)

# %%
plt.figure(figsize=(10,10))
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(10,10))
stopwords.add('said')
alice_wc.generate(alice_novel)
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from PIL import Image
alice_mask = np.array(Image.open('alice_mask.png'))

# %%
plt.figure(figsize=(10,10))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)
alice_wc.generate(alice_novel)
plt.figure(figsize=(10,10))
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
